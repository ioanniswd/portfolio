# %%
import requests
import seaborn as sns
import plotly.express as px
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import time

# %%
file_prefix = '../data/schools_attica'

# %%
df = pd.read_csv(f'{file_prefix}.csv')
df
# Out:
#         Κατηγορία                       Σχολείο  Κωδικός  \
# 0        Γυμνάσια  12ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501150
# 1        Γυμνάσια  13ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501160
# 2        Γυμνάσια  14ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501170
# 3        Γυμνάσια  15ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501180
# 4        Γυμνάσια  16ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501190
# ...           ...                           ...      ...
# 3067  Νηπιαγωγεία  ΕΙΔΙΚΟ ΝΗΠΙΑΓΩΓΕΙΟ ΕΛΕΥΣΙΝΑΣ  9521062
# 3068  Νηπιαγωγεία   ΕΙΔΙΚΟ ΝΗΠΙΑΓΩΓΕΙΟ ΖΕΦΥΡΙΟΥ  9521495
# 3069  Νηπιαγωγεία            ΝΗΠΙΑΓΩΓΕΙΟ ΒΙΛΙΩΝ  9050620
# 3070  Νηπιαγωγεία           ΝΗΠΙΑΓΩΓΕΙΟ ΕΡΥΘΡΩΝ  9050657
# 3071  Νηπιαγωγεία             ΝΗΠΙΑΓΩΓΕΙΟ ΦΥΛΗΣ  9050297
#
#                                       Διεύθυνση  \
# 0            ΚΕΙΡΙΑΔΩΝ ΚΑΙ ΣΦΗΤΤΙΩΝ 1, ΤΚ 11854
# 1         ΑΛΦΕΙΩΝΙΑΣ 10-12 & ΒΟΥΤΣΙΝΑ, ΤΚ 11632
# 2                         ΑΝ.ΖΙΝΝΗ 28, ΤΚ 11741
# 3                           ΡΗΝΕΙΑΣ 2, ΤΚ 11362
# 4             Πανόρμου και Λαρίσης 47, ΤΚ 11524
# ...                                         ...
# 3067                      ΟΔ. ΕΛΥΤΗ 2, ΤΚ 19200
# 3068                        ΣΟΥΛΙΟΥ 9, ΤΚ 13461
# 3069  Μεγάλου Αλεξάνδρου & Κιθαιρώνος, ΤΚ 19012
# 3070                   ΑΝΕΞΑΡΤΗΣΙΑΣ 2, ΤΚ 19008
# 3071                    ΑΣΠΡΟΠΥΡΓΟΥ 6, ΤΚ 13351
#
#               Περιφερειακή Διεύθυνση
# 0           ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 1           ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 2           ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 3           ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 4           ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# ...                              ...
# 3067  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3068  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3069  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3070  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3071  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
#
# [3072 rows x 5 columns]

# %%
# remove the ΤΚ from the postal code
df['Διεύθυνση'] = df['Διεύθυνση'].str.replace('ΤΚ', '')

# %%
# replace multiple spaces with a single space
df['Διεύθυνση'] = df['Διεύθυνση'].str.replace(' +', ' ')

# %%
df
# Out:
#         Κατηγορία                       Σχολείο  Κωδικός  \
# 0        Γυμνάσια  12ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501150
# 1        Γυμνάσια  13ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501160
# 2        Γυμνάσια  14ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501170
# 3        Γυμνάσια  15ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501180
# 4        Γυμνάσια  16ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501190
# ...           ...                           ...      ...
# 3067  Νηπιαγωγεία  ΕΙΔΙΚΟ ΝΗΠΙΑΓΩΓΕΙΟ ΕΛΕΥΣΙΝΑΣ  9521062
# 3068  Νηπιαγωγεία   ΕΙΔΙΚΟ ΝΗΠΙΑΓΩΓΕΙΟ ΖΕΦΥΡΙΟΥ  9521495
# 3069  Νηπιαγωγεία            ΝΗΠΙΑΓΩΓΕΙΟ ΒΙΛΙΩΝ  9050620
# 3070  Νηπιαγωγεία           ΝΗΠΙΑΓΩΓΕΙΟ ΕΡΥΘΡΩΝ  9050657
# 3071  Νηπιαγωγεία             ΝΗΠΙΑΓΩΓΕΙΟ ΦΥΛΗΣ  9050297
#
#                                     Διεύθυνση          Περιφερειακή Διεύθυνση
# 0            ΚΕΙΡΙΑΔΩΝ ΚΑΙ ΣΦΗΤΤΙΩΝ 1,  11854        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 1         ΑΛΦΕΙΩΝΙΑΣ 10-12 & ΒΟΥΤΣΙΝΑ,  11632        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 2                         ΑΝ.ΖΙΝΝΗ 28,  11741        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 3                           ΡΗΝΕΙΑΣ 2,  11362        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 4             Πανόρμου και Λαρίσης 47,  11524        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# ...                                       ...                             ...
# 3067                      ΟΔ. ΕΛΥΤΗ 2,  19200  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3068                        ΣΟΥΛΙΟΥ 9,  13461  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3069  Μεγάλου Αλεξάνδρου & Κιθαιρώνος,  19012  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3070                   ΑΝΕΞΑΡΤΗΣΙΑΣ 2,  19008  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3071                    ΑΣΠΡΟΠΥΡΓΟΥ 6,  13351  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
#
# [3072 rows x 5 columns]

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

# %%
def get_coordinates(address):
    overpass_query = f"""
    [out:json];
    node["addr:street"="{address}"];
    out center;
    """
    response = requests.get(overpass_url, params={'data': overpass_query})
    data = response.json()

    if len(data['elements']) == 0:
        return None, None

    return data['elements'][0]['lat'], data['elements'][0]['lon']

# %%
for (idx, address) in df['Διεύθυνση'].tail(20).items():
    lat, lon = get_coordinates(address)
    df.loc[idx, 'lat'] = lat
    df.loc[idx, 'lon'] = lon

# %%
with open('../google_maps_api_key') as f:
    api_key = f.read()

# %%
url = f'https://maps.googleapis.com/maps/api/geocode/json'

# %%
# get the coordinates using google maps api
for (idx, address) in df['Διεύθυνση'].head(3).items():
# for (idx, address) in df['Διεύθυνση'].items():
    if pd.notnull(df.loc[idx, 'lat']) or pd.notnull(df.loc[idx, 'lon']):
        continue

    search_params = {
        'address': address,
        'key': api_key
    }

    response = requests.get(url, params=search_params)
    data = response.json()
#     print(data)
    try:
        lat = data['results'][0]['geometry']['location']['lat']
        lon = data['results'][0]['geometry']['location']['lng']
        df.loc[idx, 'lat'] = lat
        df.loc[idx, 'lon'] = lon
    except:
        print('Error in response')
        print('Response: ', data)
        print('Address: ', address)
        print('Moving on...')
        print("\n")
# Out:
# Error in response
# Response:  {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started', 'results': [], 'status': 'REQUEST_DENIED'}
# Address:  ΡΗΝΕΙΑΣ 2,  11362
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΤΣΕΜΠΕΡΛΙΔΗ 5,  19014
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΣΩΤΗΡΟΣ 11,  19023
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΠΑΠΑΓΙΑΝΝΟΠΟΥΛΟΥ ΚΑΙ ΑΓΙΑΣ ΤΡΙΑΔΟΣ,  19442
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΠΑΠΑΓΙΑΝΝΟΠΟΥΛΟΥ ΚΑΙ ΑΓΙΑΣ ΤΡΙΑΔΟΣ,  19442
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΒΙΤΥΒΙΛΙΑ 34,  13122
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΒΙΤΥΒΙΛΙΑ 34,  13122
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΚΟΡΥΤΣΑΣ 6,  12431
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΑΝ.ΡΩΜΥΛΙΑΣ 103,  16562
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  Αγίας Ελεούσας 28,  17675
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΤΡΙΑΚΟΣΤΗ ΠΕΜΠΤΗ ΟΔΟΣ,  16777
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΧΑΤΖΗΒΑΣΙΛΕΙΟΥ 1,  17342
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  Μ.ΑΣΙΑΣ 93,  16562
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΕΛΕΥΘΕΡΙΟΥ ΒΕΝΙΖΕΛΟΥ 32,
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  Aρμοδίου 5,  1734
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΟΔΥΣΣΕΑ ΑΝΔΡΟΥΤΣΟΥ 34,  1745
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  nan
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  Μ. ΑΣΙΑΣ 93,  16562
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΑΠΟΣΤΟΛΑΚΗ 2,  17122
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΛΟΥΡΟΥ 8 & ΠΑΜΒΩΤΙΔΟΣ 9,  13341
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΣΟΥΛΙΟΥ ΚΑΙ ΚΟΥΤΣΟΝΙΚΑ,  13461
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΑΓΙΟΣ ΙΩΑΝΝΗΣ ΧΟΡΕΥΤΑΡΑΣ (ΓΑΛΙΛΑΙΟΣ),  19100
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΚΥΠΡΑΙΟΥ 45,  19200
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΑΝΕΞΑΡΤΗΣΙΑΣ 2-4,  19008
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΟΡΘΟΔΟΞΙΑΣ,  13341
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΦΙΛΙΚΗΣ ΕΤΑΙΡΕΙΑΣ -ΠΑΠΑΦΛΕΣΣΑ,  13461
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΠΑΛΙΓΓΙΝΗ 17,  19600
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΔΑΡΔΑΝΕΛΙΩΝ 85,  19200
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΔΑΡΔΑΝΕΛΙΩΝ 85,  19200
# Moving on...
#
#
# Error in response
# Response:  {'results': [], 'status': 'ZERO_RESULTS'}
# Address:  ΑΝΕΞΑΡΤΗΣΙΑΣ 2,  19008
# Moving on...

# %%
df
# Out:
#         Κατηγορία                       Σχολείο  Κωδικός  \
# 0        Γυμνάσια  12ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501150
# 1        Γυμνάσια  13ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501160
# 2        Γυμνάσια  14ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501170
# 3        Γυμνάσια  15ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501180
# 4        Γυμνάσια  16ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ   501190
# ...           ...                           ...      ...
# 3067  Νηπιαγωγεία  ΕΙΔΙΚΟ ΝΗΠΙΑΓΩΓΕΙΟ ΕΛΕΥΣΙΝΑΣ  9521062
# 3068  Νηπιαγωγεία   ΕΙΔΙΚΟ ΝΗΠΙΑΓΩΓΕΙΟ ΖΕΦΥΡΙΟΥ  9521495
# 3069  Νηπιαγωγεία            ΝΗΠΙΑΓΩΓΕΙΟ ΒΙΛΙΩΝ  9050620
# 3070  Νηπιαγωγεία           ΝΗΠΙΑΓΩΓΕΙΟ ΕΡΥΘΡΩΝ  9050657
# 3071  Νηπιαγωγεία             ΝΗΠΙΑΓΩΓΕΙΟ ΦΥΛΗΣ  9050297
#
#                                     Διεύθυνση          Περιφερειακή Διεύθυνση  \
# 0            ΚΕΙΡΙΑΔΩΝ ΚΑΙ ΣΦΗΤΤΙΩΝ 1,  11854        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 1         ΑΛΦΕΙΩΝΙΑΣ 10-12 & ΒΟΥΤΣΙΝΑ,  11632        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 2                         ΑΝ.ΖΙΝΝΗ 28,  11741        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 3                           ΡΗΝΕΙΑΣ 2,  11362        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# 4             Πανόρμου και Λαρίσης 47,  11524        ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ
# ...                                       ...                             ...
# 3067                      ΟΔ. ΕΛΥΤΗ 2,  19200  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3068                        ΣΟΥΛΙΟΥ 9,  13461  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3069  Μεγάλου Αλεξάνδρου & Κιθαιρώνος,  19012  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3070                   ΑΝΕΞΑΡΤΗΣΙΑΣ 2,  19008  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3071                    ΑΣΠΡΟΠΥΡΓΟΥ 6,  13351  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
#
#             lat        lon
# 0     37.974195  23.711097
# 1     37.957304  23.744174
# 2     37.963601  23.723498
# 3           NaN        NaN
# 4      37.99344  23.761897
# ...         ...        ...
# 3067  37.907589  23.719371
# 3068  37.932442  23.743177
# 3069  38.153709  23.343673
# 3070       None       None
# 3071  38.101987  23.667161
#
# [3072 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Κατηγορία                   0
# Σχολείο                     0
# Κωδικός                     0
# Διεύθυνση                  61
# Περιφερειακή Διεύθυνση      0
# lat                       139
# lon                       139
# dtype: int64

# %%
len(df)
# Out:
# 3072

# %%
pd.set_option('display.max_rows', 100)

# %%
df[(df['lat'].isna()) & (~df['Διεύθυνση'].isna())]
# Out:
#              Κατηγορία                                            Σχολείο  \
# 3             Γυμνάσια                       15ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΘΗΝΩΝ
# 208           Γυμνάσια                  1ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΚΑΠΑΝΔΡΙΤΙΟΥ
# 227           Γυμνάσια  2ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΜΑΡΚΟΠΟΥΛΟΥ ΜΕΣΟΓΑΙΑΣ ΑΤΤ...
# 231           Γυμνάσια                               3ο ΓΥΜΝΑΣΙΟ ΚΟΡΩΠΙΟΥ
# 332             Λύκεια                          2ο ΓΕΝΙΚΟ ΛΥΚΕΙΟ ΚΟΡΩΠΙΟΥ
# 338             Λύκεια              2ο ΗΜΕΡΗΣΙΟ ΓΕΝΙΚΟ ΛΥΚΕΙΟ ΜΑΡΚΟΠΟΥΛΟΥ
# 343             Λύκεια      5ο ΗΜΕΡΗΣΙΟ ΓΕΝΙΚΟ ΛΥΚΕΙΟ ΑΧΑΡΝΩΝ - ΑΓΙΑ ΑΝΝΑ
# 344             Λύκεια                  6ο ΗΜΕΡΗΣΙΟ ΓΕΝΙΚΟ ΛΥΚΕΙΟ ΑΧΑΡΝΕΣ
# 352             Λύκεια                ΗΜΕΡΗΣΙΟ ΓΕΝΙΚΟ ΛΥΚΕΙΟ ΑΓ. ΣΤΕΦΑΝΟΥ
# 575           Γυμνάσια               3ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΓΙΩΝ ΑΝΑΡΓΥΡΩΝ
# 656             Λύκεια            2ο ΗΜΕΡΗΣΙΟ ΓΕΝΙΚΟ ΛΥΚΕΙΟ ΑΓ. ΑΝΑΡΓΥΡΩΝ
# 680             Λύκεια                    7ο ΗΜΕΡΗΣΙΟ ΓΕΝΙΚΟ ΛΥΚΕΙΟ ΙΛΙΟΥ
# 687             Λύκεια            ΠΕΙΡΑΜΑΤΙΚΟ ΓΕΝΙΚΟ ΛΥΚΕΙΟ ΑΓ. ΑΝΑΡΓΥΡΩΝ
# 700           Γυμνάσια               1ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ ΑΓΙΟΥ ΔΗΜΗΤΡΙΟΥ
# 715           Γυμνάσια                     2ο ΗΜΕΡΗΣΙΟ ΓΥΜΝΑΣΙΟ 
# 2190  9051029             ΚΑΡΑΘΕΟΔΩΡΗ ΚΑΙ ΟΥΡΑΝΗ 16,  11525
# 2203  9051208             ΚΑΡΑΘΕΟΔΩΡΗ ΚΑΙ ΟΥΡΑΝΗ 16,  11525
# 2239  9051538                           ΧΕΙΛΩΝΩΣ 19,  15345
# 2257  9051139                            ΠΑΡΝΗΘΑΣ 1,  13562
# 2275  9050350                             ΑΙΓΙΝΗΣ 8,  12443
# 2424  7053055                            ΕΛ. ΒΕΝΙΖΕΛΟΥ 81,
# 2443  9520558        ΚΩΝΣΤΑΝΤΙΝΟΥΠΟΛΕΩΣ ΚΑΙ ΑΡΤΑΣ 2,  13562
# 2457  9051064                          ΒΙΤΥΒΙΛΙΑ 34,  13122
# 2497  9051593                          ΒΙΤΥΒΙΛΙΑ 34,  13122
# 2563  9050989                            ΚΟΡΥΤΣΑΣ 6,  12431
# 2615  9051174                       ΑΝ.ΡΩΜΥΛΙΑΣ 103,  16562
# 2650  9520407                     Αγίας Ελεούσας 28,  17675
# 2656  9050179                 ΤΡΙΑΚΟΣΤΗ ΠΕΜΠΤΗ ΟΔΟΣ,  16777
# 2671  9050143                      ΧΑΤΖΗΒΑΣΙΛΕΙΟΥ 1,  17342
# 2694  9050207                            Μ.ΑΣΙΑΣ 93,  16562
# 2776  7054195                     ΕΛΕΥΘΕΡΙΟΥ ΒΕΝΙΖΕΛΟΥ 32,
# 2805  7054113                             Aρμοδίου 5,  1734
# 2807  7054133                  ΟΔΥΣΣΕΑ ΑΝΔΡΟΥΤΣΟΥ 34,  1745
# 2928  9051254                           Μ. ΑΣΙΑΣ 93,  16562
# 2929  9520397                          ΑΠΟΣΤΟΛΑΚΗ 2,  17122
# 2946  9051851               ΛΟΥΡΟΥ 8 & ΠΑΜΒΩΤΙΔΟΣ 9,  13341
# 2961  9050287                ΣΟΥΛΙΟΥ ΚΑΙ ΚΟΥΤΣΟΝΙΚΑ,  13461
# 2987  9050649  ΑΓΙΟΣ ΙΩΑΝΝΗΣ ΧΟΡΕΥΤΑΡΑΣ (ΓΑΛΙΛΑΙΟΣ),  19100
# 2997  9050633                           ΚΥΠΡΑΙΟΥ 45,  19200
# 3000  9051900                      ΑΝΕΞΑΡΤΗΣΙΑΣ 2-4,  19008
# 3017  9050265                            ΟΡΘΟΔΟΞΙΑΣ,  13341
# 3020  9050242         ΦΙΛΙΚΗΣ ΕΤΑΙΡΕΙΑΣ -ΠΑΠΑΦΛΕΣΣΑ,  13461
# 3021  9050635                          ΠΑΛΙΓΓΙΝΗ 17,  19600
# 3025  9050624                        ΔΑΡΔΑΝΕΛΙΩΝ 85,  19200
# 3058  9050847                        ΔΑΡΔΑΝΕΛΙΩΝ 85,  19200
# 3070  9050657                        ΑΝΕΞΑΡΤΗΣΙΑΣ 2,  19008
#
#                  Περιφερειακή Διεύθυνση   lat   lon
# 3              ΔΙΕΥΘΥΝΣΗ Δ.Ε. Α΄ ΑΘΗΝΑΣ   NaN   NaN
# 208   ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 227   ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 231   ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 332   ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 338   ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 343   ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 344   ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 352   ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 575            ΔΙΕΥΘΥΝΣΗ Δ.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 656            ΔΙΕΥΘΥΝΣΗ Δ.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 680            ΔΙΕΥΘΥΝΣΗ Δ.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 687            ΔΙΕΥΘΥΝΣΗ Δ.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 700            ΔΙΕΥΘΥΝΣΗ Δ.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 715            ΔΙΕΥΘΥΝΣΗ Δ.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 785            ΔΙΕΥΘΥΝΣΗ Δ.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 837      ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 844      ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 847      ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 873      ΔΙΕΥΘΥΝΣΗ Δ.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 954            ΔΙΕΥΘΥΝΣΗ Π.Ε. Α΄ ΑΘΗΝΑΣ   NaN   NaN
# 960            ΔΙΕΥΘΥΝΣΗ Π.Ε. Α΄ ΑΘΗΝΑΣ   NaN   NaN
# 1121           ΔΙΕΥΘΥΝΣΗ Π.Ε. Α΄ ΑΘΗΝΑΣ   NaN   NaN
# 1259           ΔΙΕΥΘΥΝΣΗ Π.Ε. Α΄ ΑΘΗΝΑΣ   NaN   NaN
# 1278           ΔΙΕΥΘΥΝΣΗ Π.Ε. Α΄ ΑΘΗΝΑΣ   NaN   NaN
# 1356           ΔΙΕΥΘΥΝΣΗ Π.Ε. Α΄ ΑΘΗΝΑΣ   NaN   NaN
# 1466  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1474  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1527  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1555  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1668  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1694  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1717  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1768  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1801  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1836  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1853  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 1858           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 1882           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 1923           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 1984           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 1987           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 1988           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 2012           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 2048           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 2154           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 2169           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 2190           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 2203           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 2239           ΔΙΕΥΘΥΝΣΗ Π.Ε. Β΄ ΑΘΗΝΑΣ   NaN   NaN
# 2257           ΔΙΕΥΘΥΝΣΗ Π.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2275           ΔΙΕΥΘΥΝΣΗ Π.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2424           ΔΙΕΥΘΥΝΣΗ Π.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2443           ΔΙΕΥΘΥΝΣΗ Π.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2457           ΔΙΕΥΘΥΝΣΗ Π.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2497           ΔΙΕΥΘΥΝΣΗ Π.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2563           ΔΙΕΥΘΥΝΣΗ Π.Ε. Γ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2615           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2650           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2656           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2671           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2694           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2776           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2805           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2807           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2928           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2929           ΔΙΕΥΘΥΝΣΗ Π.Ε. Δ΄ ΑΘΗΝΑΣ   NaN   NaN
# 2946     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 2961     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 2987     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 2997     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 3000     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 3017     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 3020     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 3021     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 3025     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ   NaN   NaN
# 3058     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ  None  None
# 3070     ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ  None  None

# %%
# address = 'ΠΑΠΑΦΛΕΣΣΑ 6, 13461'
address = 'Papaflessa 6, 13461'

# %%
search_params = {
    'address': address,
    'key': api_key
}

response = requests.get(url, params=search_params)
data = response.json()

# %%
data
# Out:
# {'results': [{'address_components': [{'long_name': '6',
#      'short_name': '6',
#      'types': ['street_number']},
#     {'long_name': 'Papaflessa',
#      'short_name': 'Papaflessa',
#      'types': ['route']},
#     {'long_name': 'Agii Anargiri',
#      'short_name': 'Agii Anargiri',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ditikos Tomeas Athinon',
#      'short_name': 'Ditikos Tomeas Athinon',
#      'types': ['administrative_area_level_3', 'political']},
#     {'long_name': 'Greece',
#      'short_name': 'GR',
#      'types': ['country', 'political']},
#     {'long_name': '135 62', 'short_name': '135 62', 'types': ['postal_code']}],
#    'formatted_address': 'Papaflessa 6, Agii Anargiri 135 62, Greece',
#    'geometry': {'bounds': {'northeast': {'lat': 38.0346844, 'lng': 23.725197},
#      'southwest': {'lat': 38.0345513, 'lng': 23.7250503}},
#     'location': {'lat': 38.0346179, 'lng': 23.7251236},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 38.0359880802915,
#       'lng': 23.7264726302915},
#      'southwest': {'lat': 38.0332901197085, 'lng': 23.7237746697085}}},
#    'place_id': 'ChIJrYzS1leioRQRDW7gAc-wlts',
#    'types': ['premise']}],
#  'status': 'OK'}

# %% [markdown]
# There is a different postal code for the above address. I can only assume there is some error in the inputed data. Any address not found will have to be fixed by hand.

# %%
df.tail()
# Out:
#         Κατηγορία                       Σχολείο  Κωδικός  \
# 3067  Νηπιαγωγεία  ΕΙΔΙΚΟ ΝΗΠΙΑΓΩΓΕΙΟ ΕΛΕΥΣΙΝΑΣ  9521062
# 3068  Νηπιαγωγεία   ΕΙΔΙΚΟ ΝΗΠΙΑΓΩΓΕΙΟ ΖΕΦΥΡΙΟΥ  9521495
# 3069  Νηπιαγωγεία            ΝΗΠΙΑΓΩΓΕΙΟ ΒΙΛΙΩΝ  9050620
# 3070  Νηπιαγωγεία           ΝΗΠΙΑΓΩΓΕΙΟ ΕΡΥΘΡΩΝ  9050657
# 3071  Νηπιαγωγεία             ΝΗΠΙΑΓΩΓΕΙΟ ΦΥΛΗΣ  9050297
#
#                                     Διεύθυνση          Περιφερειακή Διεύθυνση  \
# 3067                      ΟΔ. ΕΛΥΤΗ 2,  19200  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3068                        ΣΟΥΛΙΟΥ 9,  13461  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3069  Μεγάλου Αλεξάνδρου & Κιθαιρώνος,  19012  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3070                   ΑΝΕΞΑΡΤΗΣΙΑΣ 2,  19008  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
# 3071                    ΑΣΠΡΟΠΥΡΓΟΥ 6,  13351  ΔΙΕΥΘΥΝΣΗ Π.Ε. ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ
#
#             lat        lon
# 3067  37.907589  23.719371
# 3068  37.932442  23.743177
# 3069  38.153709  23.343673
# 3070       None       None
# 3071  38.101987  23.667161

# %% [markdown]
# Address `Μεγάλου Αλεξάνδρου & Κιθαιρώνος, 19012` was found. For now, we can keep only the schools whose coordinates we know.

# %%
df['Κατηγορία'].value_counts()
# Out:
# Κατηγορία
# Νηπιαγωγεία                                          926
# Δημοτικά Σχολεία                                     787
# Ιδιωτικά Σχολεία                                     610
# Γυμνάσια                                             367
# Λύκεια                                               272
# Επαγγελματικά Λύκεια                                  74
# Σχολικό Εργαστηριακό Κέντρο                           27
# Ειδικής Επαγγελματικής Εκπαίδευσης και Κατάρτισης      9
# Name: count, dtype: int64

# %%
df['Type'] = np.where(df['Κατηγορία'] == 'Ιδιωτικά Σχολεία', 'Private', 'Public')

# %%
# df.to_csv(f'{file_prefix}_coordinates.csv', index=False)

# %%
df = pd.read_csv(f'{file_prefix}_coordinates.csv')

# %%
df.isna().sum()
# Out:
# Κατηγορία                   0
# Σχολείο                     0
# Κωδικός                     0
# Διεύθυνση                  61
# Περιφερειακή Διεύθυνση      0
# lat                       139
# lon                       139
# Τύπος                       0
# Type                        0
# dtype: int64

# %%
# create a large plotly express map graph
fig = px.scatter_mapbox(
    df,
    lat='lat',
    lon='lon',
    hover_name='Σχολείο',
    # color='Κατηγορία'
    )

fig.update_layout(
        mapbox_style='open-street-map',
        margin=dict(l=20, r=20, t=20, b=20),
        height=1000,
        width=1400
        )

fig.show()
# Out:
# <div>                            <div id="b8fa937c-9b8f-4dd4-bc31-f70275dfbf9e" class="plotly-graph-div" style="height:1000px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8fa937c-9b8f-4dd4-bc31-f70275dfbf9e")) {                    Plotly.newPlot(                        "b8fa937c-9b8f-4dd4-bc31-f70275dfbf9e",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["12\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","13\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","14\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","15\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","16\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","17\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","18\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","19\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","1\u03bf \u0395\u03a3\u03a0\u0395\u03a1\u0399\u039d\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0392\u03a5\u03a1\u03a9\u039d\u0391","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0393\u0391\u039b\u0391\u03a4\u03a3\u0399\u039f\u03a5","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0394\u0391\u03a6\u039d\u0397\u03a3","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0396\u03a9\u0393\u03a1\u0391\u03a6\u039f\u03a5","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0397\u039b\u0399\u039f\u03a5\u03a0\u039f\u039b\u0397\u03a3","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u039a\u0391\u0399\u03a3\u0391\u03a1\u0399\u0391\u039d\u0397\u03a3 - \u0394\u0397\u039c\u0397\u03a4\u03a1\u0397\u03a3 \u039a\u0391\u03a1\u0391\u039c\u039f\u039b\u0395\u0393\u039a\u039f\u03a3","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u039d\u0395\u0391\u03a3 \u03a6\u0399\u039b\u0391\u0394\u0395\u039b\u03a6\u0395\u0399\u0391\u03a3","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u03a5\u039c\u0397\u03a4\u03a4\u039f\u03a5","1\u03bf \u03a0\u0395\u0399\u03a1\u0391\u039c\u0391\u03a4\u0399\u039a\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u0391\u03a3","20\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","21\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","23\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\ ...

# %%
# create a large plotly express map graph
fig = px.scatter_mapbox(
    df,
    lat='lat',
    lon='lon',
    hover_name='Σχολείο',
    color='Type'
    )

fig.update_layout(
        mapbox_style='open-street-map',
        margin=dict(l=20, r=20, t=20, b=20),
        height=1000,
        width=1400
        )

fig.show()
# Out:
# <div>                            <div id="27cf37f8-4ae0-4c23-b98e-68c2f9675813" class="plotly-graph-div" style="height:1000px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27cf37f8-4ae0-4c23-b98e-68c2f9675813")) {                    Plotly.newPlot(                        "27cf37f8-4ae0-4c23-b98e-68c2f9675813",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eType=Public\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["12\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","13\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","14\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","15\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","16\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","17\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","18\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","19\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","1\u03bf \u0395\u03a3\u03a0\u0395\u03a1\u0399\u039d\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0392\u03a5\u03a1\u03a9\u039d\u0391","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0393\u0391\u039b\u0391\u03a4\u03a3\u0399\u039f\u03a5","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0394\u0391\u03a6\u039d\u0397\u03a3","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0396\u03a9\u0393\u03a1\u0391\u03a6\u039f\u03a5","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0397\u039b\u0399\u039f\u03a5\u03a0\u039f\u039b\u0397\u03a3","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u039a\u0391\u0399\u03a3\u0391\u03a1\u0399\u0391\u039d\u0397\u03a3 - \u0394\u0397\u039c\u0397\u03a4\u03a1\u0397\u03a3 \u039a\u0391\u03a1\u0391\u039c\u039f\u039b\u0395\u0393\u039a\u039f\u03a3","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u039d\u0395\u0391\u03a3 \u03a6\u0399\u039b\u0391\u0394\u0395\u039b\u03a6\u0395\u0399\u0391\u03a3","1\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u03a5\u039c\u0397\u03a4\u03a4\u039f\u03a5","1\u03bf \u03a0\u0395\u0399\u03a1\u0391\u039c\u0391\u03a4\u0399\u039a\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u0391\u03a3","20\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","21\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f \u0393\u03a5\u039c\u039d\u0391\u03a3\u0399\u039f \u0391\u0398\u0397\u039d\u03a9\u039d","23\u03bf \u0397\u039c\u0395\u03a1\u0397\u03a3\u0399\u039f  ...
